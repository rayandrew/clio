# %%
import pandas as pd
import numpy as np

# %%
csv_file_path = '/home/cc/clio/runs/raw/tencent/characteristic/1063/1m/characteristic.csv'
df_data = pd.read_csv(csv_file_path)
df_data
# Out:
#        num_io    start_time      end_time ts_unit    duration  read_count  \
# 0       44447  2.016100e+00  5.999894e+04      ms  59996.9210       34562
# 1       39680  6.000000e+04  1.200000e+05      ms  59999.9955       30502
# 2       54722  1.200000e+05  1.799998e+05      ms  59999.7992       41966
# 3       60007  1.800000e+05  2.399997e+05      ms  59999.7043       42857
# 4       61624  2.400000e+05  2.999997e+05      ms  59999.6803       45108
# ...       ...           ...           ...     ...         ...         ...
# 12889   12520  7.809600e+08  7.810190e+08      ms  59000.0000       10473
# 12890    1008  7.810200e+08  7.810790e+08      ms  59003.7286         874
# 12891    2777  7.810800e+08  7.811394e+08      ms  59350.9745        2417
# 12892   35835  7.811400e+08  7.811998e+08      ms  59787.1000       26245
# 12893     259  7.812000e+08  7.812008e+08      ms    772.4691         256
#
#        write_count  read_ratio  write_ratio  read_write_ratio  ...  \
# 0             9885      0.7776       0.2224            3.4964  ...
# 1             9178      0.7687       0.2313            3.3234  ...
# 2            12756      0.7669       0.2331            3.2899  ...
# 3            17150      0.7142       0.2858            2.4990  ...
# 4            16516      0.7320       0.2680            2.7312  ...
# ...            ...         ...          ...               ...  ...
# 12889         2047      0.8365       0.1635            5.1163  ...
# 12890          134      0.8671       0.1329            6.5224  ...
# 12891          360      0.8704       0.1296            6.7139  ...
# 12892         9590      0.7324       0.2676            2.7367  ...
# 12893            3      0.9884       0.0116           85.3333  ...
#
#        write_iat_p60  write_iat_p70  write_iat_p75  write_iat_p80  \
# 0           3.729411   4.979147e+00   5.848400e+00   6.968832e+00
# 1           2.945059   3.725814e+00   4.258084e+00   4.950336e+00
# 2           2.796691   3.563230e+00   4.093643e+00   4.786423e+00
# 3           2.620251   3.331978e+00   3.795400e+00   4.382209e+00
# 4           3.073399   3.934619e+00   4.516861e+00   5.253314e+00
# ...              ...            ...            ...            ...
# 12889       3.703440   5.924520e+00   7.978352e+00   1.178055e+01
# 12890     280.163417   5.553309e+02   7.391129e+02   9.988252e+02
# 12891      38.923921   8.517947e+01   1.325346e+02   2.182924e+02
# 12892       3.003849   3.766748e+00   4.260622e+00   4.888941e+00
# 12893      68.587900   7.812007e+08   7.812007e+08   7.812007e+08
#
#        write_iat_p90  write_iat_p95  write_iat_p99  write_iat_p999  \
# 0       1.098852e+01   1.596411e+01   5.030692e+01    7.842878e+02
# 1       7.663061e+00   1.241583e+01   8.160057e+01    1.343748e+03
# 2       7.564615e+00   1.211197e+01   4.439708e+01    6.563327e+02
# 3       6.372092e+00   8.842269e+00   1.951834e+01    2.683413e+02
# 4       7.810037e+00   1.087408e+01   2.038680e+01    1.308700e+02
# ...              ...            ...            ...             ...
# 12889   4.228474e+01   1.423808e+02   1.083190e+03    2.051264e+03
# 12890   1.349384e+03   1.828370e+03   1.999763e+03    1.999771e+03
# 12891   6.989813e+02   1.277835e+03   2.050381e+03    2.064848e+03
# 12892   7.348472e+00   1.204780e+01   8.057535e+01    1.183762e+03
# 12893   7.812007e+08   7.812007e+08   7.812007e+08    7.812007e+08
#
#        write_iat_p9999  write_iat_p100
# 0         1.282984e+03    1.282984e+03
# 1         2.195862e+03    2.195862e+03
# 2         1.569220e+03    1.569220e+03
# 3         1.615427e+03    1.615427e+03
# 4         7.615399e+02    7.615399e+02
# ...                ...             ...
# 12889     2.082979e+03    2.082979e+03
# 12890     1.999771e+03    1.999776e+03
# 12891     2.064848e+03    2.064848e+03
# 12892     1.835652e+03    1.835652e+03
# 12893     7.812007e+08    7.812007e+08
#
# [12894 rows x 197 columns]

# %% [markdown]
# # 1. Visualization of Data

# %%
import matplotlib.pyplot as plt

# Define categories and slice each category for visualization
categories = ['iops', 'read_write_ratio']
start_index = 1000
end_index = 2000

# %%
# Iterate through each category and plot
plt.figure(figsize=(10, 5))

for category in categories:
    data = df_data[category].iloc[start_index:end_index]  # Slice data for the current category
    plt.plot(data.index, data.values, label=category)

plt.title('Line Plot of Data Series')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(len(categories), 1, figsize=(10, 8), sharex=True)

# Iterate through each category and plot in separate subplot
for idx, category in enumerate(categories):
    data = df_data[category].iloc[start_index:end_index]  # Slice data for the current category
    axs[idx].plot(data.index, data.values, label=category)
    axs[idx].set_title(f'Line Plot of {category}')
    axs[idx].set_xlabel('Index')
    axs[idx].set_ylabel('Values')
    axs[idx].legend()
    axs[idx].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Univariate Feature Drift Detection

# %% [markdown]
# ## 2.1 Drift Detection

# %%
from alibi_detect.cd import KSDrift

# select feature category, window length and step size
category = 'iops'
window_len = 100
step_size = 50

# select reference data
data_ref = df_data[category].head(window_len).to_numpy()
cd = KSDrift(data_ref, p_val=0.005)

# %%
start = window_len
end = start + window_len
preds = []

while end < len(df_data):
    x = df_data['iops'].iloc[start:end].to_numpy()
    pred = cd.predict(x, drift_type='feature', return_p_val=True, return_distance=True)
    preds.append(pred)
    
    start += step_size
    end = start + window_len

# %%
# Initialize lists to store data for plotting
window_indices = []
is_drift_values = []
p_val_values = []
distance_values = []
threshold_values = []

# Extract data for each prediction in preds
for idx, pred in enumerate(preds):
    window_indices.append(idx + 1)  # Assuming window index starts from 1
    is_drift_values.append(pred['data']['is_drift'][0])
    p_val_values.append(pred['data']['p_val'][0])
    distance_values.append(pred['data']['distance'][0])
    threshold_values.append(pred['data']['threshold'])

# Create a DataFrame from the lists
data_dict = {
    'Window_Index': window_indices,
    'Is_Drift': is_drift_values,
    'P_Value': p_val_values,
    'Distance': distance_values,
    'Threshold': threshold_values
}

df_preds = pd.DataFrame(data_dict)
df_preds
# Out:
#      Window_Index  Is_Drift       P_Value  Distance  Threshold
# 0               1         1  3.222158e-04      0.29      0.005
# 1               2         1  3.222158e-04      0.29      0.005
# 2               3         1  1.161536e-05      0.34      0.005
# 3               4         1  4.084924e-08      0.41      0.005
# 4               5         1  1.194483e-06      0.37      0.005
# ..            ...       ...           ...       ...        ...
# 249           250         0  2.560770e-01      0.14      0.005
# 250           251         0  3.371844e-01      0.13      0.005
# 251           252         0  4.337680e-01      0.12      0.005
# 252           253         0  1.383963e-01      0.16      0.005
# 253           254         0  6.877558e-02      0.18      0.005
#
# [254 rows x 5 columns]

# %%
num_drifts = df_preds['Is_Drift'].sum()
print(f'Number of drifts detected: {num_drifts}')
# Out:
# Number of drifts detected: 182

# %%
# Get drift_window_indices and no_drift_window_indices from DataFrame
drift_window_indices = df_preds[df_preds['Is_Drift'] == 1]['Window_Index'].tolist()
no_drift_window_indices = df_preds[df_preds['Is_Drift'] == 0]['Window_Index'].tolist()

# %% [markdown]
# ## 2.2 Visualization of Prediction

# %%
# Visualization example
plt.figure(figsize=(12, 10))

# Plot is_drift
plt.subplot(3, 1, 1)
plt.plot(window_indices, is_drift_values, marker='o', linestyle='-', color='b')
plt.title('Is Drift')
plt.xlabel('Window Index')
plt.ylabel('Is Drift')

# Plot p_val
plt.subplot(3, 2, 3)
plt.plot(window_indices, p_val_values, marker='o', linestyle='-', color='g', label='p-value')
plt.plot(window_indices, threshold_values, linestyle='--', color='r', label='Threshold')
plt.title('p-value')
plt.xlabel('Window Index')
plt.ylabel('p-value')
plt.legend()

# Plot distance
plt.subplot(3, 2, 4)
plt.plot(window_indices, distance_values, marker='o', linestyle='-', color='m')
plt.title('Distance')
plt.xlabel('Window Index')
plt.ylabel('K-S Distance')

plt.tight_layout()
plt.show()

# %%
drift_index = 12

if drift_index in drift_window_indices:
    print(f'Window {drift_index} is a drift window')
# Out:
# Window 12 is a drift window

# %%
indices = np.arange(len(data_ref))  # Assuming x-axis is indexed by data points

start = drift_index * step_size
end = start + window_len
drift_data = df_data[category].iloc[start:end].to_numpy()

# Calculate rounded values for distance and keyvalue
rounded_distance = round(distance_values[drift_index - 1], 5)
rounded_keyvalue = p_val_values[drift_index - 1]

print(f'Distance: {rounded_distance}')
print(f'Keyvalue: {rounded_keyvalue}')

# Plotting both drift data and reference data
plt.figure(figsize=(8, 4))
plt.plot(indices, drift_data, marker='o', linestyle='-', color='b', label='Drift Data')
plt.plot(indices, data_ref, marker='s', linestyle='--', color='g', label='Reference Data')
plt.title(f'Drift Data vs Reference Data for window {start}:{end}')
plt.xlabel('Data Points')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Distance: 0.6700000166893005
# Keyvalue: 1.14090213797052e-22

# %% [markdown]
# ## 2.3 Visualization of Prediction by Ranking

# %%
# Rank the p-values from lowest to highest
df_sorted_pval = df_preds.sort_values(by='P_Value')

# Select the top five p-values and their corresponding window indices
top_five_drifts = df_sorted_pval.head(5)

top_five_drifts
# Out:
#      Window_Index  Is_Drift       P_Value  Distance  Threshold
# 31             32         1  0.000000e+00      0.88      0.005
# 32             33         1  0.000000e+00      0.88      0.005
# 119           120         1  1.255100e-31      0.77      0.005
# 84             85         1  1.338013e-30      0.76      0.005
# 202           203         1  1.338013e-30      0.76      0.005

# %%
# Select the bottom five p-values and their corresponding window indices
top_five_non_drifts = df_sorted_pval.tail(5)

top_five_non_drifts
# Out:
#      Window_Index  Is_Drift   P_Value  Distance  Threshold
# 7               8         0  0.662311      0.10      0.005
# 218           219         0  0.662311      0.10      0.005
# 64             65         0  0.779267      0.09      0.005
# 209           210         0  0.779267      0.09      0.005
# 245           246         0  0.952714      0.07      0.005

# %%
# Function to visualize drift data for given window indices
def visualize(window_indices, step_size, window_len, df_data, category='iops', visualize_type='Drift'):
    for window_index in window_indices:
        start = window_index * step_size
        end = start + window_len
        drift_data = df_data[category].iloc[start:end].to_numpy()
        
        plt.figure(figsize=(8, 4))
        indices = np.arange(len(drift_data))  # Assuming x-axis is indexed by data points
        plt.plot(indices, drift_data, marker='o', linestyle='-', color='b', label=f'{visualize_type} Data Window {window_index}')
        plt.plot(indices, data_ref, marker='s', linestyle='--', color='g', label='Reference Data')
        plt.title(f'Drift Data for Window Index {window_index} ({start}:{end})')
        plt.xlabel('Data Points')
        plt.ylabel('Values')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# %%
visualize(top_five_drifts['Window_Index'].tolist(), step_size, window_len, df_data, visualize_type='Drift')

# %%
visualize(top_five_non_drifts['Window_Index'].tolist(), step_size, window_len, df_data, visualize_type='Non-Drift')

# %% [markdown]
# # 3. Multivariate Feature Drift Detection

# %% [markdown]
# ## 3.1 Drift Detection

# %%
# select feature category, window length and step size
category = ['iops', 'read_write_ratio']
window_len = 100
step_size = 50

# select reference data
data_ref = df_data[category].head(window_len).to_numpy()
cd = KSDrift(data_ref, p_val=0.005, correction='fdr')

# %%
start = window_len
end = start + window_len
preds = []

while end < len(df_data):
    x = df_data[category].iloc[start:end].to_numpy()
    pred = cd.predict(x, drift_type='batch', return_p_val=True, return_distance=True)
    preds.append(pred)
    
    start += step_size
    end = start + window_len

# %%
preds
# Out:
# [{'data': {'is_drift': 1,
#    'distance': array([0.29, 0.18], dtype=float32),
#    'p_val': array([0.00032222, 0.06877558], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.29, 0.2 ], dtype=float32),
#    'p_val': array([0.00032222, 0.03143878], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.34, 0.22], dtype=float32),
#    'p_val': array([1.1615359e-05, 1.3210342e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.41, 0.27], dtype=float32),
#    'p_val': array([4.0849244e-08, 1.0387666e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.37, 0.25], dtype=float32),
#    'p_val': array([1.1944828e-06, 3.0657621e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.25, 0.22], dtype=float32),
#    'p_val': array([0.00306576, 0.01321034], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.2 , 0.29], dtype=float32),
#    'p_val': array([0.03143878, 0.00032222], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.1 , 0.28], dtype=float32),
#    'p_val': array([6.6231126e-01, 5.8501225e-04], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.31, 0.19], dtype=float32),
#    'p_val': array([9.1365175e-05, 4.6989329e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.44, 0.23], dtype=float32),
#    'p_val': array([2.4837117e-09, 8.2944632e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.56, 0.26], dtype=float32),
#    'p_val': array([2.6460562e-15, 1.8041986e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.67, 0.28], dtype=float32),
#    'p_val': array([1.1409021e-22, 5.8501225e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.39, 0.17], dtype=float32),
#    'p_val': array([2.3221384e-07, 9.8583758e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.21, 0.17], dtype=float32),
#    'p_val': array([0.02059624, 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2 , 0.22], dtype=float32),
#    'p_val': array([0.03143878, 0.01321034], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.24, 0.19], dtype=float32),
#    'p_val': array([0.00509742, 0.04698933], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.26, 0.18], dtype=float32),
#    'p_val': array([0.0018042 , 0.06877558], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.33, 0.19], dtype=float32),
#    'p_val': array([2.3643144e-05, 4.6989329e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.46, 0.2 ], dtype=float32),
#    'p_val': array([3.3604003e-10, 3.1438779e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.59, 0.26], dtype=float32),
#    'p_val': array([4.1410941e-17, 1.8041986e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.65, 0.28], dtype=float32),
#    'p_val': array([3.6227825e-21, 5.8501225e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.68, 0.29], dtype=float32),
#    'p_val': array([1.8843137e-23, 3.2221581e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.48, 0.25], dtype=float32),
#    'p_val': array([4.0692408e-11, 3.0657621e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.24, 0.13], dtype=float32),
#    'p_val': array([0.00509742, 0.3371844 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2 , 0.11], dtype=float32),
#    'p_val': array([0.03143878, 0.5439008 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.15, 0.08], dtype=float32),
#    'p_val': array([0.19026366, 0.8808397 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.23, 0.11], dtype=float32),
#    'p_val': array([0.00829446, 0.5439008 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.34, 0.15], dtype=float32),
#    'p_val': array([1.1615359e-05, 1.9026366e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.4, 0.2], dtype=float32),
#    'p_val': array([9.863563e-08, 3.143878e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.53, 0.33], dtype=float32),
#    'p_val': array([1.2438660e-13, 2.3643144e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.75, 0.61], dtype=float32),
#    'p_val': array([1.3182073e-29, 2.1577786e-18], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.88, 0.8 ], dtype=float32),
#    'p_val': array([0.00000e+00, 6.04661e-35], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.88, 0.81], dtype=float32),
#    'p_val': array([0.0000000e+00, 3.8539236e-36], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.59, 0.5 ], dtype=float32),
#    'p_val': array([4.1410941e-17, 4.3928537e-12], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.4 , 0.17], dtype=float32),
#    'p_val': array([9.863563e-08, 9.858376e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.31, 0.15], dtype=float32),
#    'p_val': array([9.1365175e-05, 1.9026366e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.18, 0.1 ], dtype=float32),
#    'p_val': array([0.06877558, 0.66231126], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.14, 0.11], dtype=float32),
#    'p_val': array([0.256077 , 0.5439008], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.19, 0.16], dtype=float32),
#    'p_val': array([0.04698933, 0.13839626], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.41, 0.23], dtype=float32),
#    'p_val': array([4.0849244e-08, 8.2944632e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.48, 0.25], dtype=float32),
#    'p_val': array([4.0692408e-11, 3.0657621e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.22, 0.16], dtype=float32),
#    'p_val': array([0.01321034, 0.13839626], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.16, 0.09], dtype=float32),
#    'p_val': array([0.13839626, 0.77926695], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.24, 0.15], dtype=float32),
#    'p_val': array([0.00509742, 0.19026366], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.23, 0.15], dtype=float32),
#    'p_val': array([0.00829446, 0.19026366], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.35, 0.19], dtype=float32),
#    'p_val': array([5.5735236e-06, 4.6989329e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.33, 0.19], dtype=float32),
#    'p_val': array([2.3643144e-05, 4.6989329e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.26, 0.18], dtype=float32),
#    'p_val': array([0.0018042 , 0.06877558], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2 , 0.18], dtype=float32),
#    'p_val': array([0.03143878, 0.06877558], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.11, 0.17], dtype=float32),
#    'p_val': array([0.5439008 , 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.21, 0.15], dtype=float32),
#    'p_val': array([0.02059624, 0.19026366], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.25, 0.16], dtype=float32),
#    'p_val': array([0.00306576, 0.13839626], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.51, 0.22], dtype=float32),
#    'p_val': array([1.3805797e-12, 1.3210342e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.68, 0.29], dtype=float32),
#    'p_val': array([1.8843137e-23, 3.2221581e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.69, 0.3 ], dtype=float32),
#    'p_val': array([2.9584830e-24, 1.7353261e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.7 , 0.31], dtype=float32),
#    'p_val': array([4.4054509e-25, 9.1365175e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.7 , 0.32], dtype=float32),
#    'p_val': array([4.4054509e-25, 4.7016918e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.55, 0.3 ], dtype=float32),
#    'p_val': array([9.8699879e-15, 1.7353261e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.22, 0.18], dtype=float32),
#    'p_val': array([0.01321034, 0.06877558], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.48, 0.41], dtype=float32),
#    'p_val': array([4.0692408e-11, 4.0849244e-08], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.61, 0.5 ], dtype=float32),
#    'p_val': array([2.1577786e-18, 4.3928537e-12], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.6 , 0.46], dtype=float32),
#    'p_val': array([9.6340709e-18, 3.3604003e-10], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.39, 0.22], dtype=float32),
#    'p_val': array([2.3221384e-07, 1.3210342e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.18, 0.14], dtype=float32),
#    'p_val': array([0.06877558, 0.256077  ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.09, 0.17], dtype=float32),
#    'p_val': array([0.77926695, 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.17, 0.17], dtype=float32),
#    'p_val': array([0.09858376, 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2 , 0.17], dtype=float32),
#    'p_val': array([0.03143878, 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.22, 0.18], dtype=float32),
#    'p_val': array([0.01321034, 0.06877558], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.35, 0.17], dtype=float32),
#    'p_val': array([5.5735236e-06, 9.8583758e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.61, 0.24], dtype=float32),
#    'p_val': array([2.1577786e-18, 5.0974246e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.73, 0.27], dtype=float32),
#    'p_val': array([1.0304550e-27, 1.0387666e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.74, 0.32], dtype=float32),
#    'p_val': array([1.2064598e-28, 4.7016918e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.71, 0.32], dtype=float32),
#    'p_val': array([6.2059028e-26, 4.7016918e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.7 , 0.28], dtype=float32),
#    'p_val': array([4.4054509e-25, 5.8501225e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.47, 0.17], dtype=float32),
#    'p_val': array([1.1859769e-10, 9.8583758e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.47, 0.19], dtype=float32),
#    'p_val': array([1.1859769e-10, 4.6989329e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.66, 0.3 ], dtype=float32),
#    'p_val': array([6.5806297e-22, 1.7353261e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.66, 0.31], dtype=float32),
#    'p_val': array([6.5806297e-22, 9.1365175e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.7 , 0.32], dtype=float32),
#    'p_val': array([4.4054509e-25, 4.7016918e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.72, 0.32], dtype=float32),
#    'p_val': array([8.2466479e-27, 4.7016918e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.73, 0.25], dtype=float32),
#    'p_val': array([1.030455e-27, 3.065762e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.74, 0.24], dtype=float32),
#    'p_val': array([1.2064598e-28, 5.0974246e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.73, 0.29], dtype=float32),
#    'p_val': array([1.030455e-27, 3.222158e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.73, 0.3 ], dtype=float32),
#    'p_val': array([1.0304550e-27, 1.7353261e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.76, 0.36], dtype=float32),
#    'p_val': array([1.338013e-30, 2.611469e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.72, 0.35], dtype=float32),
#    'p_val': array([8.2466479e-27, 5.5735236e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.49, 0.24], dtype=float32),
#    'p_val': array([1.3566927e-11, 5.0974246e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.38, 0.25], dtype=float32),
#    'p_val': array([5.3320116e-07, 3.0657621e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.62, 0.44], dtype=float32),
#    'p_val': array([4.6472801e-19, 2.4837117e-09], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.58, 0.43], dtype=float32),
#    'p_val': array([1.7155134e-16, 6.4845818e-09], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.63, 0.46], dtype=float32),
#    'p_val': array([9.6125438e-20, 3.3604003e-10], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.51, 0.34], dtype=float32),
#    'p_val': array([1.3805797e-12, 1.1615359e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.34, 0.12], dtype=float32),
#    'p_val': array([1.1615359e-05, 4.3376797e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.3 , 0.14], dtype=float32),
#    'p_val': array([1.7353261e-04, 2.5607699e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.25, 0.15], dtype=float32),
#    'p_val': array([0.00306576, 0.19026366], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.16, 0.1 ], dtype=float32),
#    'p_val': array([0.13839626, 0.66231126], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.17, 0.18], dtype=float32),
#    'p_val': array([0.09858376, 0.06877558], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.25, 0.17], dtype=float32),
#    'p_val': array([0.00306576, 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2 , 0.16], dtype=float32),
#    'p_val': array([0.03143878, 0.13839626], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.21, 0.17], dtype=float32),
#    'p_val': array([0.02059624, 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.24, 0.19], dtype=float32),
#    'p_val': array([0.00509742, 0.04698933], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.21, 0.23], dtype=float32),
#    'p_val': array([0.02059624, 0.00829446], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.44, 0.3 ], dtype=float32),
#    'p_val': array([2.4837117e-09, 1.7353261e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.69, 0.32], dtype=float32),
#    'p_val': array([2.9584830e-24, 4.7016918e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.72, 0.32], dtype=float32),
#    'p_val': array([8.2466479e-27, 4.7016918e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.73, 0.36], dtype=float32),
#    'p_val': array([1.030455e-27, 2.611469e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.74, 0.32], dtype=float32),
#    'p_val': array([1.2064598e-28, 4.7016918e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.72, 0.28], dtype=float32),
#    'p_val': array([8.2466479e-27, 5.8501225e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.73, 0.29], dtype=float32),
#    'p_val': array([1.030455e-27, 3.222158e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.75, 0.28], dtype=float32),
#    'p_val': array([1.3182073e-29, 5.8501225e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.75, 0.29], dtype=float32),
#    'p_val': array([1.3182073e-29, 3.2221581e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.75, 0.34], dtype=float32),
#    'p_val': array([1.3182073e-29, 1.1615359e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.71, 0.36], dtype=float32),
#    'p_val': array([6.205903e-26, 2.611469e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.72, 0.38], dtype=float32),
#    'p_val': array([8.2466479e-27, 5.3320116e-07], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.74, 0.41], dtype=float32),
#    'p_val': array([1.2064598e-28, 4.0849244e-08], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.74, 0.35], dtype=float32),
#    'p_val': array([1.2064598e-28, 5.5735236e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.75, 0.34], dtype=float32),
#    'p_val': array([1.3182073e-29, 1.1615359e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.75, 0.42], dtype=float32),
#    'p_val': array([1.3182073e-29, 1.6488711e-08], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.76, 0.52], dtype=float32),
#    'p_val': array([1.3380130e-30, 4.2088487e-13], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.77, 0.52], dtype=float32),
#    'p_val': array([1.2551002e-31, 4.2088487e-13], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.73, 0.43], dtype=float32),
#    'p_val': array([1.0304550e-27, 6.4845818e-09], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.46, 0.28], dtype=float32),
#    'p_val': array([3.3604003e-10, 5.8501225e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.14, 0.1 ], dtype=float32),
#    'p_val': array([0.256077  , 0.66231126], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.11, 0.07], dtype=float32),
#    'p_val': array([0.5439008, 0.9527143], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.13, 0.08], dtype=float32),
#    'p_val': array([0.3371844, 0.8808397], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.32, 0.18], dtype=float32),
#    'p_val': array([4.7016918e-05, 6.8775579e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.43, 0.22], dtype=float32),
#    'p_val': array([6.4845818e-09, 1.3210342e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.4 , 0.19], dtype=float32),
#    'p_val': array([9.863563e-08, 4.698933e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.61, 0.29], dtype=float32),
#    'p_val': array([2.1577786e-18, 3.2221581e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.76, 0.31], dtype=float32),
#    'p_val': array([1.3380130e-30, 9.1365175e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.74, 0.29], dtype=float32),
#    'p_val': array([1.2064598e-28, 3.2221581e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.71, 0.24], dtype=float32),
#    'p_val': array([6.2059028e-26, 5.0974246e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.71, 0.22], dtype=float32),
#    'p_val': array([6.2059028e-26, 1.3210342e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.45, 0.17], dtype=float32),
#    'p_val': array([9.261188e-10, 9.858376e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.27, 0.15], dtype=float32),
#    'p_val': array([0.00103877, 0.19026366], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.52, 0.25], dtype=float32),
#    'p_val': array([4.2088487e-13, 3.0657621e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.69, 0.28], dtype=float32),
#    'p_val': array([2.9584830e-24, 5.8501225e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.71, 0.27], dtype=float32),
#    'p_val': array([6.2059028e-26, 1.0387666e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.71, 0.28], dtype=float32),
#    'p_val': array([6.2059028e-26, 5.8501225e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.7, 0.3], dtype=float32),
#    'p_val': array([4.4054509e-25, 1.7353261e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.65, 0.25], dtype=float32),
#    'p_val': array([3.6227825e-21, 3.0657621e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.25, 0.17], dtype=float32),
#    'p_val': array([0.00306576, 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.16, 0.1 ], dtype=float32),
#    'p_val': array([0.13839626, 0.66231126], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.28, 0.14], dtype=float32),
#    'p_val': array([0.00058501, 0.256077  ], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.43, 0.21], dtype=float32),
#    'p_val': array([6.4845818e-09, 2.0596236e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.6 , 0.41], dtype=float32),
#    'p_val': array([9.6340709e-18, 4.0849244e-08], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.68, 0.52], dtype=float32),
#    'p_val': array([1.8843137e-23, 4.2088487e-13], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.58, 0.41], dtype=float32),
#    'p_val': array([1.7155134e-16, 4.0849244e-08], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.47, 0.25], dtype=float32),
#    'p_val': array([1.1859769e-10, 3.0657621e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.31, 0.15], dtype=float32),
#    'p_val': array([9.1365175e-05, 1.9026366e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.16, 0.1 ], dtype=float32),
#    'p_val': array([0.13839626, 0.66231126], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.19, 0.11], dtype=float32),
#    'p_val': array([0.04698933, 0.5439008 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.13, 0.07], dtype=float32),
#    'p_val': array([0.3371844, 0.9527143], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.35, 0.2 ], dtype=float32),
#    'p_val': array([5.5735236e-06, 3.1438779e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.26, 0.15], dtype=float32),
#    'p_val': array([0.0018042 , 0.19026366], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.18, 0.09], dtype=float32),
#    'p_val': array([0.06877558, 0.77926695], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.3 , 0.17], dtype=float32),
#    'p_val': array([0.00017353, 0.09858376], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.21, 0.21], dtype=float32),
#    'p_val': array([0.02059624, 0.02059624], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.14, 0.15], dtype=float32),
#    'p_val': array([0.256077  , 0.19026366], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.29, 0.17], dtype=float32),
#    'p_val': array([0.00032222, 0.09858376], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.38, 0.18], dtype=float32),
#    'p_val': array([5.3320116e-07, 6.8775579e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.45, 0.18], dtype=float32),
#    'p_val': array([9.261188e-10, 6.877558e-02], dtype=float32),
#    'threshold': 0.0025},
# ...
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.65, 0.5 ], dtype=float32),
#    'p_val': array([3.6227825e-21, 4.3928537e-12], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.76, 0.66], dtype=float32),
#    'p_val': array([1.3380130e-30, 6.5806297e-22], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.56, 0.41], dtype=float32),
#    'p_val': array([2.6460562e-15, 4.0849244e-08], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.34, 0.21], dtype=float32),
#    'p_val': array([1.1615359e-05, 2.0596236e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.33, 0.23], dtype=float32),
#    'p_val': array([2.3643144e-05, 8.2944632e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.34, 0.18], dtype=float32),
#    'p_val': array([1.1615359e-05, 6.8775579e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.25, 0.13], dtype=float32),
#    'p_val': array([0.00306576, 0.3371844 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.11, 0.17], dtype=float32),
#    'p_val': array([0.5439008 , 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.09, 0.21], dtype=float32),
#    'p_val': array([0.77926695, 0.02059624], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.13, 0.24], dtype=float32),
#    'p_val': array([0.3371844 , 0.00509742], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.14, 0.21], dtype=float32),
#    'p_val': array([0.256077  , 0.02059624], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1 , 0.18], dtype=float32),
#    'p_val': array([0.66231126, 0.06877558], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1, 0.2], dtype=float32),
#    'p_val': array([0.66231126, 0.03143878], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.3, 0.2], dtype=float32),
#    'p_val': array([0.00017353, 0.03143878], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.6 , 0.22], dtype=float32),
#    'p_val': array([9.6340709e-18, 1.3210342e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.27, 0.19], dtype=float32),
#    'p_val': array([0.00103877, 0.04698933], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1 , 0.18], dtype=float32),
#    'p_val': array([0.66231126, 0.06877558], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1 , 0.17], dtype=float32),
#    'p_val': array([0.66231126, 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.34, 0.2 ], dtype=float32),
#    'p_val': array([1.1615359e-05, 3.1438779e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.49, 0.23], dtype=float32),
#    'p_val': array([1.3566927e-11, 8.2944632e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.41, 0.27], dtype=float32),
#    'p_val': array([4.0849244e-08, 1.0387666e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.35, 0.22], dtype=float32),
#    'p_val': array([5.5735236e-06, 1.3210342e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.32, 0.13], dtype=float32),
#    'p_val': array([4.7016918e-05, 3.3718440e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.45, 0.2 ], dtype=float32),
#    'p_val': array([9.261188e-10, 3.143878e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.34, 0.15], dtype=float32),
#    'p_val': array([1.1615359e-05, 1.9026366e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.21, 0.16], dtype=float32),
#    'p_val': array([0.02059624, 0.13839626], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.36, 0.16], dtype=float32),
#    'p_val': array([2.6114690e-06, 1.3839626e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.46, 0.32], dtype=float32),
#    'p_val': array([3.3604003e-10, 4.7016918e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.64, 0.53], dtype=float32),
#    'p_val': array([1.906924e-20, 1.243866e-13], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.68, 0.58], dtype=float32),
#    'p_val': array([1.8843137e-23, 1.7155134e-16], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.56, 0.46], dtype=float32),
#    'p_val': array([2.6460562e-15, 3.3604003e-10], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.5 , 0.34], dtype=float32),
#    'p_val': array([4.3928537e-12, 1.1615359e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.44, 0.23], dtype=float32),
#    'p_val': array([2.4837117e-09, 8.2944632e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.36, 0.16], dtype=float32),
#    'p_val': array([2.6114690e-06, 1.3839626e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.38, 0.22], dtype=float32),
#    'p_val': array([5.3320116e-07, 1.3210342e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.36, 0.23], dtype=float32),
#    'p_val': array([2.611469e-06, 8.294463e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.3 , 0.22], dtype=float32),
#    'p_val': array([0.00017353, 0.01321034], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.36, 0.15], dtype=float32),
#    'p_val': array([2.6114690e-06, 1.9026366e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.33, 0.11], dtype=float32),
#    'p_val': array([2.3643144e-05, 5.4390079e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.21, 0.13], dtype=float32),
#    'p_val': array([0.02059624, 0.3371844 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.12, 0.15], dtype=float32),
#    'p_val': array([0.43376797, 0.19026366], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.19, 0.12], dtype=float32),
#    'p_val': array([0.04698933, 0.43376797], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2 , 0.12], dtype=float32),
#    'p_val': array([0.03143878, 0.43376797], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.18, 0.17], dtype=float32),
#    'p_val': array([0.06877558, 0.09858376], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.07, 0.14], dtype=float32),
#    'p_val': array([0.9527143, 0.256077 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.11, 0.15], dtype=float32),
#    'p_val': array([0.5439008 , 0.19026366], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.22, 0.16], dtype=float32),
#    'p_val': array([0.01321034, 0.13839626], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.37, 0.21], dtype=float32),
#    'p_val': array([1.1944828e-06, 2.0596236e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.14, 0.16], dtype=float32),
#    'p_val': array([0.256077  , 0.13839626], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.13, 0.18], dtype=float32),
#    'p_val': array([0.3371844 , 0.06877558], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.12, 0.16], dtype=float32),
#    'p_val': array([0.43376797, 0.13839626], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.16, 0.13], dtype=float32),
#    'p_val': array([0.13839626, 0.3371844 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.18, 0.08], dtype=float32),
#    'p_val': array([0.06877558, 0.8808397 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'KSDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}}]

# %%
# Initialize lists to store data for plotting
window_indices = []
is_drift_values = []
p_val_values = []
distance_values = []
threshold_values = []

# Extract data for each prediction in preds
for idx, pred in enumerate(preds):
    window_indices.append(idx + 1)  # Assuming window index starts from 1
    is_drift_values.append(pred['data']['is_drift'])
    p_val_values.append(pred['data']['p_val'])
    distance_values.append(pred['data']['distance'])
    threshold_values.append(pred['data']['threshold'])

# Create a DataFrame from the lists
data_dict = {
    'Window_Index': window_indices,
    'Is_Drift': is_drift_values,
    'P_Value': p_val_values,
    'Distance': distance_values,
    'Threshold': threshold_values
}

df_preds = pd.DataFrame(data_dict)
df_preds
# Out:
#      Window_Index  Is_Drift                        P_Value      Distance  \
# 0               1         1     [0.0003222158, 0.06877558]  [0.29, 0.18]
# 1               2         1     [0.0003222158, 0.03143878]   [0.29, 0.2]
# 2               3         1   [1.1615359e-05, 0.013210342]  [0.34, 0.22]
# 3               4         1  [4.0849244e-08, 0.0010387666]  [0.41, 0.27]
# 4               5         1   [1.1944828e-06, 0.003065762]  [0.37, 0.25]
# ..            ...       ...                            ...           ...
# 249           250         0         [0.256077, 0.13839626]  [0.14, 0.16]
# 250           251         0        [0.3371844, 0.06877558]  [0.13, 0.18]
# 251           252         0       [0.43376797, 0.13839626]  [0.12, 0.16]
# 252           253         0        [0.13839626, 0.3371844]  [0.16, 0.13]
# 253           254         0        [0.06877558, 0.8808397]  [0.18, 0.08]
#
#            Threshold
# 0             0.0025
# 1             0.0025
# 2             0.0025
# 3              0.005
# 4              0.005
# ..               ...
# 249  [0.0025, 0.005]
# 250  [0.0025, 0.005]
# 251  [0.0025, 0.005]
# 252  [0.0025, 0.005]
# 253  [0.0025, 0.005]
#
# [254 rows x 5 columns]

# %%
num_drifts = df_preds['Is_Drift'].sum()
print(f'Number of drifts detected: {num_drifts}')
# Out:
# Number of drifts detected: 177

# %%
# Get drift_window_indices and no_drift_window_indices from DataFrame
drift_window_indices = df_preds[df_preds['Is_Drift'] == 1]['Window_Index'].tolist()
no_drift_window_indices = df_preds[df_preds['Is_Drift'] == 0]['Window_Index'].tolist()

# %% [markdown]
# ## 3.2 Visualization of Predictions

# %%
# Visualization example
plt.figure(figsize=(8, 4))

# Plot is_drift
plt.plot(window_indices, is_drift_values, marker='o', linestyle='-', color='b')
plt.title('Is Drift')
plt.xlabel('Window Index')
plt.ylabel('Is Drift')

plt.tight_layout()
plt.show()

# %%
drift_index = 12

if drift_index in drift_window_indices:
    print(f'Window {drift_index} is a drift window')
# Out:
# Window 12 is a drift window

# %%
data_ref.shape
# Out:
# (100, 2)

# %%
indices = np.arange(window_len)  

for idx, cate in enumerate(category):
    start = drift_index * step_size
    end = start + window_len
    drift_data = df_data[cate].iloc[start:end].to_numpy()
    reference_data = data_ref[:,idx]

    # Plotting both drift data and reference data
    plt.figure(figsize=(8, 4))
    plt.plot(indices, drift_data, marker='o', linestyle='-', color='b', label='Drift Data')
    plt.plot(indices, reference_data, marker='s', linestyle='--', color='g', label='Reference Data')
    plt.title(f'Drift Data vs Reference Data for {category} (Window {start}:{end})')
    plt.xlabel('Data Points')
    plt.ylabel('Values')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
