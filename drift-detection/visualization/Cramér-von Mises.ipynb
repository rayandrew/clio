# %%
import pandas as pd
import numpy as np

# %%
csv_file_path = '/home/cc/clio/runs/raw/tencent/characteristic/1063/1m/characteristic.csv'
df_data = pd.read_csv(csv_file_path)
df_data
# Out:
#        num_io    start_time      end_time ts_unit    duration  read_count  \
# 0       44447  2.016100e+00  5.999894e+04      ms  59996.9210       34562
# 1       39680  6.000000e+04  1.200000e+05      ms  59999.9955       30502
# 2       54722  1.200000e+05  1.799998e+05      ms  59999.7992       41966
# 3       60007  1.800000e+05  2.399997e+05      ms  59999.7043       42857
# 4       61624  2.400000e+05  2.999997e+05      ms  59999.6803       45108
# ...       ...           ...           ...     ...         ...         ...
# 12889   12520  7.809600e+08  7.810190e+08      ms  59000.0000       10473
# 12890    1008  7.810200e+08  7.810790e+08      ms  59003.7286         874
# 12891    2777  7.810800e+08  7.811394e+08      ms  59350.9745        2417
# 12892   35835  7.811400e+08  7.811998e+08      ms  59787.1000       26245
# 12893     259  7.812000e+08  7.812008e+08      ms    772.4691         256
#
#        write_count  read_ratio  write_ratio  read_write_ratio  ...  \
# 0             9885      0.7776       0.2224            3.4964  ...
# 1             9178      0.7687       0.2313            3.3234  ...
# 2            12756      0.7669       0.2331            3.2899  ...
# 3            17150      0.7142       0.2858            2.4990  ...
# 4            16516      0.7320       0.2680            2.7312  ...
# ...            ...         ...          ...               ...  ...
# 12889         2047      0.8365       0.1635            5.1163  ...
# 12890          134      0.8671       0.1329            6.5224  ...
# 12891          360      0.8704       0.1296            6.7139  ...
# 12892         9590      0.7324       0.2676            2.7367  ...
# 12893            3      0.9884       0.0116           85.3333  ...
#
#        write_iat_p60  write_iat_p70  write_iat_p75  write_iat_p80  \
# 0           3.729411   4.979147e+00   5.848400e+00   6.968832e+00
# 1           2.945059   3.725814e+00   4.258084e+00   4.950336e+00
# 2           2.796691   3.563230e+00   4.093643e+00   4.786423e+00
# 3           2.620251   3.331978e+00   3.795400e+00   4.382209e+00
# 4           3.073399   3.934619e+00   4.516861e+00   5.253314e+00
# ...              ...            ...            ...            ...
# 12889       3.703440   5.924520e+00   7.978352e+00   1.178055e+01
# 12890     280.163417   5.553309e+02   7.391129e+02   9.988252e+02
# 12891      38.923921   8.517947e+01   1.325346e+02   2.182924e+02
# 12892       3.003849   3.766748e+00   4.260622e+00   4.888941e+00
# 12893      68.587900   7.812007e+08   7.812007e+08   7.812007e+08
#
#        write_iat_p90  write_iat_p95  write_iat_p99  write_iat_p999  \
# 0       1.098852e+01   1.596411e+01   5.030692e+01    7.842878e+02
# 1       7.663061e+00   1.241583e+01   8.160057e+01    1.343748e+03
# 2       7.564615e+00   1.211197e+01   4.439708e+01    6.563327e+02
# 3       6.372092e+00   8.842269e+00   1.951834e+01    2.683413e+02
# 4       7.810037e+00   1.087408e+01   2.038680e+01    1.308700e+02
# ...              ...            ...            ...             ...
# 12889   4.228474e+01   1.423808e+02   1.083190e+03    2.051264e+03
# 12890   1.349384e+03   1.828370e+03   1.999763e+03    1.999771e+03
# 12891   6.989813e+02   1.277835e+03   2.050381e+03    2.064848e+03
# 12892   7.348472e+00   1.204780e+01   8.057535e+01    1.183762e+03
# 12893   7.812007e+08   7.812007e+08   7.812007e+08    7.812007e+08
#
#        write_iat_p9999  write_iat_p100
# 0         1.282984e+03    1.282984e+03
# 1         2.195862e+03    2.195862e+03
# 2         1.569220e+03    1.569220e+03
# 3         1.615427e+03    1.615427e+03
# 4         7.615399e+02    7.615399e+02
# ...                ...             ...
# 12889     2.082979e+03    2.082979e+03
# 12890     1.999771e+03    1.999776e+03
# 12891     2.064848e+03    2.064848e+03
# 12892     1.835652e+03    1.835652e+03
# 12893     7.812007e+08    7.812007e+08
#
# [12894 rows x 197 columns]

# %% [markdown]
# # 1. Visualization of Data

# %%
import matplotlib.pyplot as plt

# Define categories and slice each category for visualization
categories = ['iops', 'read_write_ratio']
start_index = 1000
end_index = 2000

# %%
# Iterate through each category and plot
plt.figure(figsize=(10, 5))

for category in categories:
    data = df_data[category].iloc[start_index:end_index]  # Slice data for the current category
    plt.plot(data.index, data.values, label=category)

plt.title('Line Plot of Data Series')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(len(categories), 1, figsize=(10, 8), sharex=True)

# Iterate through each category and plot in separate subplot
for idx, category in enumerate(categories):
    data = df_data[category].iloc[start_index:end_index]  # Slice data for the current category
    axs[idx].plot(data.index, data.values, label=category)
    axs[idx].set_title(f'Line Plot of {category}')
    axs[idx].set_xlabel('Index')
    axs[idx].set_ylabel('Values')
    axs[idx].legend()
    axs[idx].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Univariate Feature Drift Detection

# %% [markdown]
# ## 2.1 Drift Detection

# %%
from alibi_detect.cd import CVMDrift

# select feature category, window length and step size
category = 'iops'
window_len = 100
step_size = 50

# select reference data
data_ref = df_data[category].head(window_len).to_numpy()
cd = CVMDrift(data_ref, p_val=0.005)

# %%
start = window_len
end = start + window_len
preds = []

while end < len(df_data):
    x = df_data['iops'].iloc[start:end].to_numpy()
    pred = cd.predict(x, drift_type='feature', return_p_val=True, return_distance=True)
    preds.append(pred)
    
    start += step_size
    end = start + window_len

# %%
# Initialize lists to store data for plotting
window_indices = []
is_drift_values = []
p_val_values = []
distance_values = []
threshold_values = []

# Extract data for each prediction in preds
for idx, pred in enumerate(preds):
    window_indices.append(idx + 1)  # Assuming window index starts from 1
    is_drift_values.append(pred['data']['is_drift'][0])
    p_val_values.append(pred['data']['p_val'][0])
    distance_values.append(pred['data']['distance'][0])
    threshold_values.append(pred['data']['threshold'])

# Create a DataFrame from the lists
data_dict = {
    'Window_Index': window_indices,
    'Is_Drift': is_drift_values,
    'P_Value': p_val_values,
    'Distance': distance_values,
    'Threshold': threshold_values
}

df_preds = pd.DataFrame(data_dict)
df_preds
# Out:
#      Window_Index  Is_Drift       P_Value  Distance  Threshold
# 0               1         1  7.059318e-06    2.1108      0.005
# 1               2         1  1.104228e-05    2.0244      0.005
# 2               3         1  9.141267e-08    2.9567      0.005
# 3               4         1  2.707035e-11    4.6417      0.005
# 4               5         1  1.287719e-08    3.3410      0.005
# ..            ...       ...           ...       ...        ...
# 249           250         0  1.761580e-01    0.2605      0.005
# 250           251         0  3.142518e-01    0.1789      0.005
# 251           252         0  3.277886e-01    0.1733      0.005
# 252           253         0  2.364969e-01    0.2179      0.005
# 253           254         0  1.521932e-01    0.2824      0.005
#
# [254 rows x 5 columns]

# %%
num_drifts = df_preds['Is_Drift'].sum()
print(f'Number of drifts detected: {num_drifts}')
# Out:
# Number of drifts detected: 186

# %%
# Get drift_window_indices and no_drift_window_indices from DataFrame
drift_window_indices = df_preds[df_preds['Is_Drift'] == 1]['Window_Index'].tolist()
no_drift_window_indices = df_preds[df_preds['Is_Drift'] == 0]['Window_Index'].tolist()

# %% [markdown]
# ## 2.2 Visualization of Prediction

# %%
# Visualization example
plt.figure(figsize=(12, 10))

# Plot is_drift
plt.subplot(3, 1, 1)
plt.plot(window_indices, is_drift_values, marker='o', linestyle='-', color='b')
plt.title('Is Drift')
plt.xlabel('Window Index')
plt.ylabel('Is Drift')

# Plot p_val
plt.subplot(3, 2, 3)
plt.plot(window_indices, p_val_values, marker='o', linestyle='-', color='g', label='p-value')
plt.plot(window_indices, threshold_values, linestyle='--', color='r', label='Threshold')
plt.title('p-value')
plt.xlabel('Window Index')
plt.ylabel('p-value')
plt.legend()

# Plot distance
plt.subplot(3, 2, 4)
plt.plot(window_indices, distance_values, marker='o', linestyle='-', color='m')
plt.title('Distance')
plt.xlabel('Window Index')
plt.ylabel('K-S Distance')

plt.tight_layout()

# %%
drift_index = 12

if drift_index in drift_window_indices:
    print(f'Window {drift_index} is a drift window')
# Out:
# Window 12 is a drift window

# %%
indices = np.arange(len(data_ref))  # Assuming x-axis is indexed by data points

start = drift_index * step_size
end = start + window_len
drift_data = df_data[category].iloc[start:end].to_numpy()

# Calculate rounded values for distance and keyvalue
rounded_distance = round(distance_values[drift_index - 1], 5)
rounded_keyvalue = p_val_values[drift_index - 1]

print(f'Distance: {rounded_distance}')
print(f'Keyvalue: {rounded_keyvalue}')

# Plotting both drift data and reference data
plt.figure(figsize=(8, 4))
plt.plot(indices, drift_data, marker='o', linestyle='-', color='b', label='Drift Data')
plt.plot(indices, data_ref, marker='s', linestyle='--', color='g', label='Reference Data')
plt.title(f'Drift Data vs Reference Data for window {start}:{end}')
plt.xlabel('Data Points')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Distance: 7.612500190734863
# Keyvalue: 9.746220497319769e-10

# %% [markdown]
# ## 2.3 Visualization of Prediction by Ranking

# %%
# Rank the p-values from lowest to highest
df_sorted_pval = df_preds.sort_values(by='P_Value')

# Select the top five p-values and their corresponding window indices
top_five_drifts = df_sorted_pval.head(5)

top_five_drifts
# Out:
#      Window_Index  Is_Drift       P_Value  Distance  Threshold
# 199           200         1  4.077738e-12    5.8230      0.005
# 59             60         1  5.720202e-12    5.9103      0.005
# 19             20         1  7.292500e-12    5.9740      0.005
# 165           166         1  1.051648e-11    6.0722      0.005
# 135           136         1  2.603118e-11    4.7497      0.005

# %%
# Select the bottom five p-values and their corresponding window indices
top_five_non_drifts = df_sorted_pval.tail(5)

top_five_non_drifts
# Out:
#      Window_Index  Is_Drift   P_Value  Distance  Threshold
# 64             65         0  0.629351    0.0923      0.005
# 7               8         0  0.642220    0.0899      0.005
# 209           210         0  0.672112    0.0845      0.005
# 218           219         0  0.672112    0.0845      0.005
# 245           246         0  0.922294    0.0432      0.005

# %%
# Function to visualize drift data for given window indices
def visualize(window_indices, step_size, window_len, df_data, category='iops', visualize_type='Drift'):
    for window_index in window_indices:
        start = window_index * step_size
        end = start + window_len
        drift_data = df_data[category].iloc[start:end].to_numpy()
        
        plt.figure(figsize=(8, 4))
        indices = np.arange(len(drift_data))  # Assuming x-axis is indexed by data points
        plt.plot(indices, drift_data, marker='o', linestyle='-', color='b', label=f'{visualize_type} Data Window {window_index}')
        plt.plot(indices, data_ref, marker='s', linestyle='--', color='g', label='Reference Data')
        plt.title(f'Drift Data for Window Index {window_index} ({start}:{end})')
        plt.xlabel('Data Points')
        plt.ylabel('Values')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# %%
visualize(top_five_drifts['Window_Index'].tolist(), step_size, window_len, df_data, visualize_type='Drift')

# %%
visualize(top_five_non_drifts['Window_Index'].tolist(), step_size, window_len, df_data, visualize_type='Non-Drift')

# %% [markdown]
# # 3. Multivariate Feature Drift Detection

# %% [markdown]
# ## 3.1 Drift Detection

# %%
# select feature category, window length and step size
category = ['iops', 'read_write_ratio']
window_len = 100
step_size = 50

# select reference data
data_ref = df_data[category].head(window_len).to_numpy()
cd = CVMDrift(data_ref, p_val=0.005, correction='fdr')

# %%
start = window_len
end = start + window_len
preds = []

while end < len(df_data):
    x = df_data[category].iloc[start:end].to_numpy()
    pred = cd.predict(x, drift_type='batch', return_p_val=True, return_distance=True)
    preds.append(pred)
    
    start += step_size
    end = start + window_len

# %%
preds
# Out:
# [{'data': {'is_drift': 1,
#    'distance': array([2.1108, 0.5041], dtype=float32),
#    'p_val': array([7.059318e-06, 3.888603e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.0244, 0.6437], dtype=float32),
#    'p_val': array([1.1042281e-05, 1.7435482e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.9567, 0.7173], dtype=float32),
#    'p_val': array([9.1412666e-08, 1.1529648e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.6417, 0.9285], dtype=float32),
#    'p_val': array([2.7070346e-11, 3.6019832e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.341 , 0.7033], dtype=float32),
#    'p_val': array([1.28771855e-08, 1.24684200e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.3729  , 0.564525], dtype=float32),
#    'p_val': array([0.00033316, 0.02738693], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.8365  , 1.055225], dtype=float32),
#    'p_val': array([0.00595783, 0.00181361], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.0899, 1.0361], dtype=float32),
#    'p_val': array([0.6422199 , 0.00201058], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.6015, 0.6895], dtype=float32),
#    'p_val': array([9.9997473e-05, 1.3470887e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.4497, 0.7402], dtype=float32),
#    'p_val': array([7.41305950e-09, 1.01476805e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([5.6316  , 0.842425], dtype=float32),
#    'p_val': array([5.0366711e-10, 5.7669748e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([7.6125  , 0.899725], dtype=float32),
#    'p_val': array([9.7462205e-10, 4.2138076e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.9623, 0.4002], dtype=float32),
#    'p_val': array([8.8833694e-08, 7.2266452e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.6778, 0.4218], dtype=float32),
#    'p_val': array([0.0143857 , 0.06339221], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.6417, 0.762 ], dtype=float32),
#    'p_val': array([0.01763388, 0.00898986], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.8062, 0.6025], dtype=float32),
#    'p_val': array([0.00703967, 0.02203231], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([0.9963, 0.4679], dtype=float32),
#    'p_val': array([0.00249297, 0.04812314], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.9167, 0.6639], dtype=float32),
#    'p_val': array([1.9309315e-05, 1.5556307e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.9025, 0.8799], dtype=float32),
#    'p_val': array([8.9303531e-10, 4.6960185e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([5.974 , 0.7712], dtype=float32),
#    'p_val': array([7.292500e-12, 8.542731e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([7.079 , 0.9146], dtype=float32),
#    'p_val': array([2.5350044e-10, 3.8853497e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.0257  , 0.922425], dtype=float32),
#    'p_val': array([2.8084979e-11, 3.7231471e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.2911  , 0.531375], dtype=float32),
#    'p_val': array([1.0511847e-10, 3.3170477e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.9175  , 0.208075], dtype=float32),
#    'p_val': array([0.00382441, 0.25368366], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.7425, 0.0859], dtype=float32),
#    'p_val': array([0.01001862, 0.66423935], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.4495, 0.0791], dtype=float32),
#    'p_val': array([0.0536857 , 0.70325303], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.8574, 0.1122], dtype=float32),
#    'p_val': array([0.00531193, 0.5325935 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.7642, 0.2527], dtype=float32),
#    'p_val': array([2.4474065e-07, 1.8572208e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.3417, 0.476 ], dtype=float32),
#    'p_val': array([8.2203466e-11, 4.5871556e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([7.3803, 1.3853], dtype=float32),
#    'p_val': array([5.5543425e-10, 3.1201457e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([12.254125,  6.6063  ], dtype=float32),
#    'p_val': array([1.6641756e-09, 6.4143579e-11], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([14.845375, 11.56235 ], dtype=float32),
#    'p_val': array([1.6897617e-09, 5.9515848e-10], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([15.184775, 11.8758  ], dtype=float32),
#    'p_val': array([2.4781195e-09, 9.6242236e-10], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.4733, 3.4321], dtype=float32),
#    'p_val': array([8.654322e-11, 8.105318e-09], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.8655, 0.4336], dtype=float32),
#    'p_val': array([1.0199747e-09, 5.9045397e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.6646, 0.3033], dtype=float32),
#    'p_val': array([7.1858740e-05, 1.3273175e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.393 , 0.1137], dtype=float32),
#    'p_val': array([0.07551555, 0.5259998 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1721, 0.1047], dtype=float32),
#    'p_val': array([0.33078024, 0.56700146], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.797 , 0.2414], dtype=float32),
#    'p_val': array([0.0074064 , 0.20066707], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.0946, 0.9908], dtype=float32),
#    'p_val': array([4.5202363e-08, 2.5683118e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.7435, 1.1437], dtype=float32),
#    'p_val': array([1.7275328e-09, 1.1276987e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.5492, 0.2522], dtype=float32),
#    'p_val': array([0.0299171, 0.1863554], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.3295, 0.0697], dtype=float32),
#    'p_val': array([0.1121763 , 0.76006806], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.979 , 0.3032], dtype=float32),
#    'p_val': array([0.00273784, 0.1328179 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.9515, 0.3977], dtype=float32),
#    'p_val': array([0.00317846, 0.07337712], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.2193, 0.6192], dtype=float32),
#    'p_val': array([4.0293962e-06, 2.0033803e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.0089, 0.5969], dtype=float32),
#    'p_val': array([1.1966103e-05, 2.2747906e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.9485, 0.5142], dtype=float32),
#    'p_val': array([0.00323069, 0.03665742], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.5325, 0.3682], dtype=float32),
#    'p_val': array([0.03295457, 0.08797991], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.121 , 0.2449], dtype=float32),
#    'p_val': array([0.49522713, 0.1958933 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.4806, 0.2261], dtype=float32),
#    'p_val': array([0.04464282, 0.22320002], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.089 , 0.2758], dtype=float32),
#    'p_val': array([0.00151224, 0.15899831], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.844   , 0.850425], dtype=float32),
#    'p_val': array([1.1098618e-09, 5.5191386e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([7.4347, 1.1169], dtype=float32),
#    'p_val': array([6.3563399e-10, 1.3018721e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.1217 , 1.19205], dtype=float32),
#    'p_val': array([3.6126102e-11, 8.7081781e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.6493, 1.3   ], dtype=float32),
#    'p_val': array([1.305035e-10, 4.902198e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.8559, 1.9988], dtype=float32),
#    'p_val': array([2.0702373e-10, 1.2609458e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.556   , 1.471425], dtype=float32),
#    'p_val': array([3.3330338e-11, 1.9806765e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.4415, 0.3942], dtype=float32),
#    'p_val': array([0.05631431, 0.07496323], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([5.9103, 2.253 ], dtype=float32),
#    'p_val': array([5.7202021e-12, 3.3861158e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.5585, 3.6603], dtype=float32),
#    'p_val': array([1.0580381e-10, 2.5775715e-09], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.3593, 2.9816], dtype=float32),
#    'p_val': array([6.5719874e-11, 8.0491297e-08], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.5432  , 0.628625], dtype=float32),
#    'p_val': array([4.6206661e-09, 1.8989788e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.4072, 0.2517], dtype=float32),
#    'p_val': array([0.06925209, 0.1869912 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.0923, 0.3732], dtype=float32),
#    'p_val': array([0.629351, 0.085297], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.4375, 0.3497], dtype=float32),
#    'p_val': array([0.05767985, 0.09874097], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.779   , 0.373975], dtype=float32),
#    'p_val': array([0.00818151, 0.0848892 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.8235  , 0.462675], dtype=float32),
#    'p_val': array([0.0063995 , 0.04963755], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.4686, 0.4867], dtype=float32),
#    'p_val': array([1.1154576e-06, 4.3066867e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([6.853   , 0.811925], dtype=float32),
#    'p_val': array([1.345466e-10, 6.820878e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.4517  , 0.957125], dtype=float32),
#    'p_val': array([7.0004202e-10, 3.0828137e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.928   , 1.322825], dtype=float32),
#    'p_val': array([1.6699381e-09, 4.3431864e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.6947 , 1.15005], dtype=float32),
#    'p_val': array([1.4470081e-10, 1.0900078e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.5176  , 1.049325], dtype=float32),
#    'p_val': array([9.6122998e-11, 1.8721969e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.8706  , 0.544275], dtype=float32),
#    'p_val': array([1.0004652e-09, 3.0781157e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.6862, 0.4505], dtype=float32),
#    'p_val': array([2.2712845e-09, 5.3366438e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([7.6909, 1.0757], dtype=float32),
#    'p_val': array([1.1694302e-09, 1.6243430e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([7.5368, 1.2637], dtype=float32),
#    'p_val': array([8.1445783e-10, 5.9448415e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.4948, 1.2578], dtype=float32),
#    'p_val': array([9.1079255e-11, 6.1343331e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.343 , 1.1005], dtype=float32),
#    'p_val': array([5.6701699e-10, 1.4216505e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.7035, 0.8304], dtype=float32),
#    'p_val': array([1.1202607e-09, 6.1610616e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.834 , 0.9202], dtype=float32),
#    'p_val': array([1.4159911e-09, 3.7685547e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.8504, 1.4129], dtype=float32),
#    'p_val': array([1.4576629e-09, 2.6968052e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.9381, 1.9688], dtype=float32),
#    'p_val': array([1.69948644e-09, 1.47326955e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.3616,  2.8745], dtype=float32),
#    'p_val': array([7.2298056e-11, 1.3916407e-07], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.6706, 2.6035], dtype=float32),
#    'p_val': array([1.0549674e-09, 5.5782999e-07], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.8426, 1.2599], dtype=float32),
#    'p_val': array([1.1161597e-09, 6.0661975e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.1861, 0.7572], dtype=float32),
#    'p_val': array([4.7830245e-06, 9.2325937e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.1506, 2.4276], dtype=float32),
#    'p_val': array([3.8573800e-10, 1.3773113e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.78605 , 2.782925], dtype=float32),
#    'p_val': array([1.7754809e-10, 2.2236240e-07], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.65095, 2.9152 ], dtype=float32),
#    'p_val': array([1.01760211e-09, 1.13014615e-07], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([6.766525, 1.622175], dtype=float32),
#    'p_val': array([1.04415365e-10, 8.97294376e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.714   , 0.191225], dtype=float32),
#    'p_val': array([3.1651777e-07, 2.8675637e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.1771, 0.2534], dtype=float32),
#    'p_val': array([5.0106742e-06, 1.8483964e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.5911, 0.2913], dtype=float32),
#    'p_val': array([1.0560163e-04, 1.4353551e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.5081  , 0.089475], dtype=float32),
#    'p_val': array([0.03798682, 0.6445257 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2844  , 0.327725], dtype=float32),
#    'p_val': array([0.1501971 , 0.11345053], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.0869, 0.2873], dtype=float32),
#    'p_val': array([0.00152941, 0.14735541], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.6092, 0.2657], dtype=float32),
#    'p_val': array([0.02120676, 0.17009765], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.6628, 0.2489], dtype=float32),
#    'p_val': array([0.01565304, 0.19059862], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.8488, 0.4028], dtype=float32),
#    'p_val': array([0.00556859, 0.0711306 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.8495  , 0.594025], dtype=float32),
#    'p_val': array([0.00554723, 0.02312462], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.2758  , 0.967025], dtype=float32),
#    'p_val': array([1.7945512e-08, 2.9215296e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.8309, 1.2514], dtype=float32),
#    'p_val': array([1.9600488e-10, 6.3467899e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.5407, 1.3601], dtype=float32),
#    'p_val': array([8.2893648e-10, 3.5650143e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.1276  ,  1.893575], dtype=float32),
#    'p_val': array([2.3466225e-09, 2.1775091e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.255   ,  1.696675], dtype=float32),
#    'p_val': array([2.8957461e-09, 6.0763236e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.4309  , 1.036575], dtype=float32),
#    'p_val': array([6.7262407e-10, 2.0054358e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.5997  , 0.865325], dtype=float32),
#    'p_val': array([9.2561936e-10, 5.0861123e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.0026,  1.2056], dtype=float32),
#    'p_val': array([1.899344e-09, 8.100716e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.3647,  1.7078], dtype=float32),
#    'p_val': array([7.2737816e-11, 5.7331577e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.8635,  2.351 ], dtype=float32),
#    'p_val': array([1.8460533e-10, 2.0430882e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.968 , 2.8857], dtype=float32),
#    'p_val': array([1.7896926e-09, 1.3141607e-07], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.4536,  3.0089], dtype=float32),
#    'p_val': array([8.6428864e-11, 7.0013535e-08], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([11.2829,  3.5119], dtype=float32),
#    'p_val': array([3.7917836e-10, 5.4108398e-09], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.7871  ,  2.855525], dtype=float32),
#    'p_val': array([1.6095414e-10, 1.5334989e-07], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([11.0291  ,  2.720525], dtype=float32),
#    'p_val': array([2.4688485e-10, 3.0610926e-07], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.5678,  3.8713], dtype=float32),
#    'p_val': array([1.0740775e-10, 9.9783970e-10], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.8834,  4.9927], dtype=float32),
#    'p_val': array([1.9125712e-10, 4.9381055e-11], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([11.6191,  4.9881], dtype=float32),
#    'p_val': array([6.5050665e-10, 4.8560822e-11], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.5244,  3.4994], dtype=float32),
#    'p_val': array([9.894818e-11, 5.763658e-09], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.1047, 1.2149], dtype=float32),
#    'p_val': array([2.6678104e-10, 7.7087438e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2212  , 0.109975], dtype=float32),
#    'p_val': array([0.23103625, 0.5425488 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.114   , 0.052925], dtype=float32),
#    'p_val': array([0.52469236, 0.8652647 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2136  , 0.056925], dtype=float32),
#    'p_val': array([0.24384324, 0.84032685], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.9772  , 0.429025], dtype=float32),
#    'p_val': array([1.41043665e-05, 6.06915355e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.6455, 0.7629], dtype=float32),
#    'p_val': array([2.7723677e-09, 8.9450795e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.1777, 0.7997], dtype=float32),
#    'p_val': array([2.958454e-08, 7.296793e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([7.4655, 0.9969], dtype=float32),
#    'p_val': array([6.8547812e-10, 2.4848913e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([11.0254,  1.4702], dtype=float32),
#    'p_val': array([2.4530966e-10, 1.9934980e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.6333,  1.3726], dtype=float32),
#    'p_val': array([1.2141099e-10, 3.3368720e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.3563,  0.7333], dtype=float32),
#    'p_val': array([7.1551209e-11, 1.0545185e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.3052,  0.5628], dtype=float32),
#    'p_val': array([6.4701355e-11, 2.7660213e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.2352, 0.2602], dtype=float32),
#    'p_val': array([1.3859480e-10, 1.7651515e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.4879, 0.1828], dtype=float32),
#    'p_val': array([1.8160963e-04, 3.0522141e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.7497, 0.7504], dtype=float32),
#    'p_val': array([2.6031177e-11, 9.5880218e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.3562, 0.9402], dtype=float32),
#    'p_val': array([6.5223160e-11, 3.3798085e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.1075, 1.0021], dtype=float32),
#    'p_val': array([3.5306236e-10, 2.4159534e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.6017  , 1.302825], dtype=float32),
#    'p_val': array([9.2906571e-10, 4.8292492e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.5533  , 1.502225], dtype=float32),
#    'p_val': array([8.4879415e-10, 1.6842259e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.4418, 1.1899], dtype=float32),
#    'p_val': array([8.0264795e-11, 8.8087143e-04], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.3434, 0.3785], dtype=float32),
#    'p_val': array([0.00038946, 0.08255027], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.5386, 0.074 ], dtype=float32),
#    'p_val': array([0.03180927, 0.7337116 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.7546  , 0.280525], dtype=float32),
#    'p_val': array([4.4903154e-05, 1.5409209e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.7768  , 0.725325], dtype=float32),
#    'p_val': array([2.6839753e-11, 1.1024599e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.0937  , 2.259925], dtype=float32),
#    'p_val': array([3.4313608e-10, 3.2672708e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.114625,  4.294025], dtype=float32),
#    'p_val': array([2.29622810e-09, 1.03621556e-10], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([7.804825, 2.3319  ], dtype=float32),
#    'p_val': array([1.514091e-09, 2.254354e-06], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([5.4189, 0.8546], dtype=float32),
#    'p_val': array([2.4263902e-10, 5.3941421e-03], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.903 , 0.3525], dtype=float32),
#    'p_val': array([2.0734054e-05, 9.7023241e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.5402  , 0.118075], dtype=float32),
#    'p_val': array([0.03151581, 0.5072991 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.5116  , 0.119625], dtype=float32),
#    'p_val': array([0.03721796, 0.50085974], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1817, 0.049 ], dtype=float32),
#    'p_val': array([0.30773646, 0.88911045], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.933, 0.441], dtype=float32),
#    'p_val': array([1.7741699e-05, 5.6483097e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.1678, 0.2437], dtype=float32),
#    'p_val': array([0.00099127, 0.19751495], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.4189, 0.0663], dtype=float32),
#    'p_val': array([0.06451225, 0.7812503 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.6786, 0.3616], dtype=float32),
#    'p_val': array([6.678491e-05, 9.166370e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.6417  , 0.473725], dtype=float32),
#    'p_val': array([0.01763388, 0.04649244], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
# ...
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([11.81845,  6.8948 ], dtype=float32),
#    'p_val': array([8.830713e-10, 1.517435e-10], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([6.74445, 2.4991 ], dtype=float32),
#    'p_val': array([9.7769570e-11, 9.5359684e-07], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.847 , 0.5948], dtype=float32),
#    'p_val': array([1.6018662e-07, 2.3022439e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.4292, 0.7415], dtype=float32),
#    'p_val': array([1.3660203e-06, 1.0074527e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.5112, 0.4456], dtype=float32),
#    'p_val': array([8.961105e-07, 5.495040e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.6257, 0.257 ], dtype=float32),
#    'p_val': array([8.8087778e-05, 1.8037733e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1837, 0.4062], dtype=float32),
#    'p_val': array([0.30318204, 0.06967427], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.0845, 0.5669], dtype=float32),
#    'p_val': array([0.6721121 , 0.02701526], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2094, 0.8255], dtype=float32),
#    'p_val': array([0.25128138, 0.00632943], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.271 , 0.6989], dtype=float32),
#    'p_val': array([0.16416623, 0.01277943], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.0998, 0.6667], dtype=float32),
#    'p_val': array([0.5908132 , 0.01531284], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1255, 0.8178], dtype=float32),
#    'p_val': array([0.47730634, 0.00660357], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.6539, 0.6246], dtype=float32),
#    'p_val': array([7.599661e-05, 1.942857e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([6.3872  , 0.918375], dtype=float32),
#    'p_val': array([3.1672220e-11, 3.8062197e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.1191, 0.453 ], dtype=float32),
#    'p_val': array([0.0012866 , 0.05257711], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1525, 0.5094], dtype=float32),
#    'p_val': array([0.38465098, 0.03769931], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.0845, 0.4533], dtype=float32),
#    'p_val': array([0.6721121 , 0.05248323], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.0033  , 0.546025], dtype=float32),
#    'p_val': array([1.2318631e-05, 3.0471180e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.3544, 0.9904], dtype=float32),
#    'p_val': array([7.7356233e-11, 2.5738801e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.9078  , 1.127975], dtype=float32),
#    'p_val': array([1.1737257e-07, 1.2268141e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.1219, 0.7126], dtype=float32),
#    'p_val': array([6.6653956e-06, 1.1836422e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.9674, 0.2957], dtype=float32),
#    'p_val': array([1.4840117e-05, 1.3946268e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.6387, 0.488 ], dtype=float32),
#    'p_val': array([2.8670777e-09, 4.2738676e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.5586, 0.2138], dtype=float32),
#    'p_val': array([1.2523634e-04, 2.4349560e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.7062, 0.2171], dtype=float32),
#    'p_val': array([0.01226771, 0.2378436 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.726 , 0.4049], dtype=float32),
#    'p_val': array([2.9764090e-07, 7.0227265e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.9105, 0.9309], dtype=float32),
#    'p_val': array([3.7161385e-11, 3.5552285e-03], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([9.02525 , 3.793125], dtype=float32),
#    'p_val': array([2.9749425e-10, 1.3774578e-09], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([10.859825,  4.694125], dtype=float32),
#    'p_val': array([1.834003e-10, 2.569378e-11], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([8.3643  , 3.114825], dtype=float32),
#    'p_val': array([6.652856e-11, 4.077002e-08], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([6.44755, 1.7568 ], dtype=float32),
#    'p_val': array([3.8651193e-11, 4.4390697e-05], dtype=float32),
#    'threshold': 0.005},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([4.9339  , 0.589025], dtype=float32),
#    'p_val': array([4.0136894e-11, 2.3795310e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.3715, 0.3865], dtype=float32),
#    'p_val': array([1.1026958e-08, 7.8585021e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.3735, 0.5439], dtype=float32),
#    'p_val': array([1.0915407e-08, 3.0848008e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.1257, 0.6992], dtype=float32),
#    'p_val': array([6.5356726e-06, 1.2757970e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([1.2497, 0.7739], dtype=float32),
#    'p_val': array([0.00064045, 0.00841588], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.7414, 0.259 ], dtype=float32),
#    'p_val': array([2.7505928e-07, 1.7795216e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([3.076 , 0.1871], dtype=float32),
#    'p_val': array([4.970366e-08, 2.956242e-01], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.9109, 0.1461], dtype=float32),
#    'p_val': array([0.00396453, 0.40449947], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.24    , 0.313925], dtype=float32),
#    'p_val': array([0.20261447, 0.12392628], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.4547  , 0.167675], dtype=float32),
#    'p_val': array([0.05204747, 0.34210074], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.3497 , 0.12805], dtype=float32),
#    'p_val': array([0.09874097, 0.46749124], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2813 , 0.15425], dtype=float32),
#    'p_val': array([0.15330397, 0.37942985], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.0432, 0.2788], dtype=float32),
#    'p_val': array([0.9222939 , 0.15586293], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1431  , 0.270225], dtype=float32),
#    'p_val': array([0.41422784, 0.16501854], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.813   , 0.330675], dtype=float32),
#    'p_val': array([0.00678058, 0.11134156], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 1,
#    'distance': array([2.012 , 0.5099], dtype=float32),
#    'p_val': array([1.1775327e-05, 3.7589341e-02], dtype=float32),
#    'threshold': 0.0025},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2605, 0.2878], dtype=float32),
#    'p_val': array([0.17615798, 0.14687167], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1789, 0.4481], dtype=float32),
#    'p_val': array([0.3142518 , 0.05413609], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.1733, 0.2252], dtype=float32),
#    'p_val': array([0.3277886 , 0.22461556], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2179  , 0.080925], dtype=float32),
#    'p_val': array([0.23649691, 0.6925943 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}},
#  {'data': {'is_drift': 0,
#    'distance': array([0.2824, 0.0398], dtype=float32),
#    'p_val': array([0.15219322, 0.9400166 ], dtype=float32),
#    'threshold': array([0.0025, 0.005 ])},
#   'meta': {'name': 'CVMDrift',
#    'online': False,
#    'data_type': None,
#    'version': '0.12.0',
#    'detector_type': 'drift'}}]

# %%
# Initialize lists to store data for plotting
window_indices = []
is_drift_values = []
p_val_values = []
distance_values = []
threshold_values = []

# Extract data for each prediction in preds
for idx, pred in enumerate(preds):
    window_indices.append(idx + 1)  # Assuming window index starts from 1
    is_drift_values.append(pred['data']['is_drift'])
    p_val_values.append(pred['data']['p_val'])
    distance_values.append(pred['data']['distance'])
    threshold_values.append(pred['data']['threshold'])

# Create a DataFrame from the lists
data_dict = {
    'Window_Index': window_indices,
    'Is_Drift': is_drift_values,
    'P_Value': p_val_values,
    'Distance': distance_values,
    'Threshold': threshold_values
}

df_preds = pd.DataFrame(data_dict)
df_preds
# Out:
#      Window_Index  Is_Drift                        P_Value  \
# 0               1         1     [7.059318e-06, 0.03888603]
# 1               2         1   [1.1042281e-05, 0.017435482]
# 2               3         1   [9.1412666e-08, 0.011529648]
# 3               4         1  [2.7070346e-11, 0.0036019832]
# 4               5         1   [1.28771855e-08, 0.01246842]
# ..            ...       ...                            ...
# 249           250         0       [0.17615798, 0.14687167]
# 250           251         0       [0.3142518, 0.054136086]
# 251           252         0        [0.3277886, 0.22461556]
# 252           253         0        [0.23649691, 0.6925943]
# 253           254         0        [0.15219322, 0.9400166]
#
#                Distance        Threshold
# 0      [2.1108, 0.5041]           0.0025
# 1      [2.0244, 0.6437]           0.0025
# 2      [2.9567, 0.7173]           0.0025
# 3      [4.6417, 0.9285]            0.005
# 4       [3.341, 0.7033]           0.0025
# ..                  ...              ...
# 249    [0.2605, 0.2878]  [0.0025, 0.005]
# 250    [0.1789, 0.4481]  [0.0025, 0.005]
# 251    [0.1733, 0.2252]  [0.0025, 0.005]
# 252  [0.2179, 0.080925]  [0.0025, 0.005]
# 253    [0.2824, 0.0398]  [0.0025, 0.005]
#
# [254 rows x 5 columns]

# %%
num_drifts = df_preds['Is_Drift'].sum()
print(f'Number of drifts detected: {num_drifts}')
# Out:
# Number of drifts detected: 181

# %%
# Get drift_window_indices and no_drift_window_indices from DataFrame
drift_window_indices = df_preds[df_preds['Is_Drift'] == 1]['Window_Index'].tolist()
no_drift_window_indices = df_preds[df_preds['Is_Drift'] == 0]['Window_Index'].tolist()

# %% [markdown]
# ## 3.2 Visualization of Predictions

# %%
# Visualization example
plt.figure(figsize=(8, 4))

# Plot is_drift
plt.plot(window_indices, is_drift_values, marker='o', linestyle='-', color='b')
plt.title('Is Drift')
plt.xlabel('Window Index')
plt.ylabel('Is Drift')

plt.tight_layout()
plt.show()

# %%
drift_index = 12

if drift_index in drift_window_indices:
    print(f'Window {drift_index} is a drift window')
# Out:
# Window 12 is a drift window

# %%
indices = np.arange(window_len)  

for idx, cate in enumerate(category):
    start = drift_index * step_size
    end = start + window_len
    drift_data = df_data[cate].iloc[start:end].to_numpy()
    reference_data = data_ref[:,idx]

    # Plotting both drift data and reference data
    plt.figure(figsize=(8, 4))
    plt.plot(indices, drift_data, marker='o', linestyle='-', color='b', label='Drift Data')
    plt.plot(indices, reference_data, marker='s', linestyle='--', color='g', label='Reference Data')
    plt.title(f'Drift Data vs Reference Data for {category} (Window {start}:{end})')
    plt.xlabel('Data Points')
    plt.ylabel('Values')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
